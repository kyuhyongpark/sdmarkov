# %% [markdown]
# # Basic analysis
#
# This notebook computes various topology metrics comparing SD, null, random Markov chains across Boolean network models.
#
# Results are cached to CSV.

# %%
import pandas as pd
import numpy as np

from sdmarkov.matrix_operations import compress_matrix
from sdmarkov.graph import get_markov_chain
from sdmarkov.analysis.model_context import iter_model_contexts
from sdmarkov.analysis.utils import generate_dataframe, network_level_metrics_df

# %%
IMPORT_CSV = False
REBUILD_CONTEXTS = False
DEBUG = False

CACHE_DIR = "../.cache/model_contexts"
CSV_FILE = "../results/basic_analysis.csv"

# Parameters for building contexts
MODEL_DIRECTORY = "../models/random_nk3"
UPDATE = "asynchronous"
N_RANDOM = 30 # number of random models
NSQUARE_STEPS = 20 # number of steps for nsquare

# %% [markdown]
# ## Data generation or loading

# %%
def get_data_topology(
    context,
    DEBUG=False,
):
    """
    Computes general network info and grouping/Markov chain statistics.

    Parameters
    ----------
    context : ModelContext
        Pre-built model context.
    DEBUG : bool, optional
        Enable verbose output in lower-level metric computations.

    Returns
    -------
    pd.DataFrame
        Long-format DataFrame with one row per method (and per random run).
        Returns an empty DataFrame if the model has fewer than two attractors.
    """

    rows = []

    # Unpack model context
    model_name = context.model_name
    update = context.update
    n_states = context.n_states
    n_nodes = context.n_nodes
    n_sources = context.n_sources
    n_perc = context.n_perc
    n_sources_perc = context.n_sources_perc
    n_attractors = context.n_attractors
    n_min_trap = context.n_min_trap
    T = context.T
    sd_indices = context.sd_indices
    null_indices = context.null_indices
    n_random = context.random.n_random
    random_indices_list = context.random.indices

    # filter out fully percolated models
    if n_states == 1:
        return pd.DataFrame(rows)

    # --- internal helper to compute metrics and append a row ---
    def _add_row(method_name, indices, run=0):
        valid_groups = [g for g in indices if g]
        group_sizes = [len(g) for g in valid_groups]
        T_group = compress_matrix(T, indices, DEBUG=DEBUG)
        mc_edges = get_markov_chain(T_group, indices, DEBUG=DEBUG).number_of_edges()

        row = {
            "model": model_name,
            "method": method_name,
            "run": run,
            "group_count": len(valid_groups),
            "group_size_mean": np.mean(group_sizes),
            "group_size_std": np.std(group_sizes),
            "mc_edges_count": mc_edges,
            "N": n_nodes,
            "sources": n_sources,
            "N_perc": n_perc,
            "sources_perc": n_sources_perc,
            "n_min_trap": n_min_trap,
            "n_attractors": n_attractors,
            "update_scheme": update
        }
        rows.append(row)

    _add_row("sd_mc", sd_indices)
    _add_row("null_mc", null_indices)

    # --- random groupings ---
    for i in range(n_random):
        random_indices = random_indices_list[i]
        _add_row("random_mc", random_indices, run=i)

    return pd.DataFrame(rows)

# %%
if IMPORT_CSV:
    df = pd.read_csv(CSV_FILE)
    print(f"Loaded cached results from {CSV_FILE}.")
else:
    ctxs = iter_model_contexts(model_directory=MODEL_DIRECTORY,
                               update=UPDATE,
                               nsquare_steps=NSQUARE_STEPS,
                               n_random=N_RANDOM,
                               cache_dir=CACHE_DIR,
                               force_rebuild=REBUILD_CONTEXTS,
                               DEBUG=DEBUG,
                               )

    df = generate_dataframe(
        model_contexts=ctxs,
        data_function=get_data_topology,
        schema={
            "group_count": int,
            "mc_edges_count": int,
            "N": int,
            "sources": int,
            "N_perc": int,
            "sources_perc": int,
            "n_min_trap": int,
            "n_states": int,
            "n_attractors": int,
            "run": "Int64",
        },
        DEBUG=DEBUG,
    )
    df.to_csv(CSV_FILE, index=False)
    print(f"Saved results to {CSV_FILE}.")
# Out:
# Preparing contexts for 1000 models
# [  1/1000] n010_000.bnet
# [  2/1000] n010_001.bnet
# [  3/1000] n010_002.bnet
# [  4/1000] n010_003.bnet
# [  5/1000] n010_004.bnet
# [  6/1000] n010_005.bnet
# [  7/1000] n010_006.bnet
# [  8/1000] n010_007.bnet
# [  9/1000] n010_008.bnet
# [ 10/1000] n010_009.bnet
# [ 11/1000] n010_010.bnet
# [ 12/1000] n010_011.bnet
# [ 13/1000] n010_012.bnet
# [ 14/1000] n010_013.bnet
# [ 15/1000] n010_014.bnet
# [ 16/1000] n010_015.bnet
# [ 17/1000] n010_016.bnet
# [ 18/1000] n010_017.bnet
# [ 19/1000] n010_018.bnet
# [ 20/1000] n010_019.bnet
# [ 21/1000] n010_020.bnet
# [ 22/1000] n010_021.bnet
# [ 23/1000] n010_022.bnet
# [ 24/1000] n010_023.bnet
# [ 25/1000] n010_024.bnet
# [ 26/1000] n010_025.bnet
# [ 27/1000] n010_026.bnet
# [ 28/1000] n010_027.bnet
# [ 29/1000] n010_028.bnet
# [ 30/1000] n010_029.bnet
# [ 31/1000] n010_030.bnet
# [ 32/1000] n010_031.bnet
# [ 33/1000] n010_032.bnet
# [ 34/1000] n010_033.bnet
# [ 35/1000] n010_034.bnet
# ...

# %%
print("Preview of results DataFrame:")
display(df.head())

print("\nDataFrame shape:", df.shape)
print("Methods present:", df.method.unique())
print("Number of unique networks:", df.model.nunique())
# Out:
# Preview of results DataFrame:
#            model     method  run  group_count  group_size_mean  \
# 0  n010_000.bnet      sd_mc    0           16        64.000000
# 1  n010_000.bnet    null_mc    0            3       341.333333
# 2  n010_000.bnet  random_mc    0           16        64.000000
# 3  n010_000.bnet  random_mc    1           16        64.000000
# 4  n010_000.bnet  random_mc    2           16        64.000000
#
#    group_size_std  mc_edges_count   N  sources  N_perc  sources_perc  \
# 0       32.000000              46  10        0      10             0
# 1      437.463395               5  10        0      10             0
# 2       13.720423             226  10        0      10             0
# 3       13.430376             226  10        0      10             0
# 4       13.448978             226  10        0      10             0
#
#    n_min_trap  n_attractors update_scheme
# 0           2             2  asynchronous
# 1           2             2  asynchronous
# ...

# %% [markdown]
# ## Data analysis

# %%
df_metrics = network_level_metrics_df(df=df)

# Compute maximum possible number of edges in the Markov chain
# Formula: (non_attractors)^2 + non_attractors * attractors + attractors^2
non_attractors = df_metrics["group_count"] - df_metrics["n_attractors"]
attractors = df_metrics["n_attractors"]

df_metrics["max_edges"] = non_attractors**2 + non_attractors * attractors + attractors**2

df_metrics["normalized_density"] = df_metrics["mc_edges_count"] / df_metrics["max_edges"]

print("Preview of network-level metrics DataFrame:")
display(df_metrics.head())

print("\nDataFrame shape:", df_metrics.shape)
print("Methods present:", df_metrics.method.unique())
print("Number of unique networks:", df_metrics.model.nunique())

metrics = ["group_count", "normalized_density"]
summary = (
    df_metrics
    .groupby("method")[metrics]
    .agg(["mean", "min", "median", "max"])
)

display(summary)

print("\nAre min_trap_count and attractor_count equal?")
print((df_metrics["n_min_trap"] == df_metrics["n_attractors"]).all())
# Out:
# Preview of network-level metrics DataFrame:
#            model     method  group_count  group_size_mean  group_size_std  \
# 0  n010_000.bnet    null_mc          3.0       341.333333      437.463395
# 1  n010_000.bnet  random_mc         16.0        64.000000       14.328153
# 2  n010_000.bnet      sd_mc         16.0        64.000000       32.000000
# 3  n010_001.bnet    null_mc          6.0        10.666667       21.171259
# 4  n010_001.bnet  random_mc         12.0         5.333333        4.015570
#
#    mc_edges_count     N  sources  N_perc  sources_perc  n_min_trap  \
# 0        5.000000  10.0      0.0    10.0           0.0         2.0
# 1      225.933333  10.0      0.0    10.0           0.0         2.0
# 2       46.000000  10.0      0.0    10.0           0.0         2.0
# 3       11.000000  10.0      0.0     6.0           1.0         5.0
# 4       68.066667  10.0      0.0     6.0           1.0         5.0
#
#    n_attractors update_scheme  max_edges  normalized_density
# ...
